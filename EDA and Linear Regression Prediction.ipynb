# %% [markdown]
# # Exploratory Data Analysis and Multiple Linear Regression on Medical Cost Personal Dataset

# %%
import sklearn
library(readr) #read in the data
#library(ggplot2) #visualization 
#library(corrplot) #visualization of correlation
#library(ggcorrplot) #visualization of correlation
#library(reshape2) #melt function
#library(dplyr) #used for data transformations
#library(tidyverse) #used for data transformations
insurance <- read_csv(file = "insurance.csv") #input the dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f2573a11f642> in <module>()
#       1 import sklearn
# ----> 2 library(readr) #read in the data
#       3 #library(ggplot2) #visualization
#       4 #library(corrplot) #visualization of correlation
#       5 #library(ggcorrplot) #visualization of correlation
#
# NameError: name 'library' is not defined

# %%
summary(insurance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-048f9dc86d93> in <module>()
# ----> 1 summary(insurance)
#
# NameError: name 'summary' is not defined
